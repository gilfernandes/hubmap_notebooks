# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
PATH = Path('/home/jupyter/reports')
assert PATH.exists()

# %%
# !ls -latr {PATH}
# Out:
# total 128
# -rw-r--r-- 1 root root 2120 Mar  8 17:59 37_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_fold_0
# -rw-r--r-- 1 root root 1767 Mar  8 21:17 37_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_fold_3
# -rw-r--r-- 1 root root 2475 Mar  9 00:03 37_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_fold_1
# -rw-r--r-- 1 root root 2652 Mar  9 03:04 37_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_fold_2
# -rw-r--r-- 1 root root 2654 Mar 15 04:37 37_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_1
# -rw-r--r-- 1 root root 2669 Mar 15 10:37 37_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_2
# -rw-r--r-- 1 root root 2648 Mar 15 16:39 37_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_3
# -rw-r--r-- 1 root root 2657 Mar 17 17:56 37_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_0
# -rw-r--r-- 1 root root 2665 Mar 18 15:53 39_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_advprop_fold_0
# -rw-r--r-- 1 root root 2657 Mar 18 21:53 39_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_advprop_fold_1
# -rw-r--r-- 1 root root 2665 Mar 19 03:45 39_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_advprop_fold_2
# -rw-r--r-- 1 root root 2477 Mar 19 09:14 39_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_advprop_fold_3
# -rw-r--r-- 1 root root 2654 Mar 20 02:03 40_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_1
# -rw-r--r-- 1 root root 2664 Mar 20 08:22 40_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_2
# -rw-r--r-- 1 root root  531 Mar 20 09:37 40_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_3
# -rw-r--r-- 1 root root 2651 Mar 22 15:10 40_pytorch_unet_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_0
# -rw-r--r-- 1 root root  706 Mar 22 19:13 40_pytorch_pan_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_0
# -rw-r--r-- 1 root root 2667 Mar 23 18:44 40_pytorch_linknet_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_0
# -rw-r--r-- 1 root root 2661 Mar 23 21:54 40_pytorch_linknet_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_1
# -rw-r--r-- 1 root root 2666 Mar 24 01:03 40_pytorch_linknet_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_2
# -rw-r--r-- 1 root root 2670 Mar 24 04:12 40_pytorch_linknet_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_new_data_fold_3
# drwxr-xr-x 7 root root   84 Mar 24 08:30 ..
# -rw-r--r-- 1 root root 2485 Mar 24 14:06 43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_double_data_fold_1
# -rw-r--r-- 1 root root 1232 Mar 24 15:13 43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_double_data_fold_2
# -rw-r--r-- 1 root root  422 Mar 24 15:41 43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_double_data_fold_0
# -rw-r--r-- 1 root root 4215 Mar 24 19:04 43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_b12_fold_0
# -rw-r--r-- 1 root root 4217 Mar 24 22:15 43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_b12_fold_1
# -rw-r--r-- 1 root root 2521 Mar 25 00:10 43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_b12_fold_2
# drwxr-xr-x 2 root root 4096 Mar 25 00:20 .
# -rw-r--r-- 1 root root 4216 Mar 25 03:22 43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_b12_fold_3

# %%
def plot_results(fpn_metrics):
    plt.figure(figsize=(15,5))
    n_e = np.arange(len(fpn_metrics['dice_metric_mean']))
    plt.plot(n_e, fpn_metrics['dice_metric_mean'], '-o', label='Valid dice metric', color='#ff7f0e')
    plt.plot(n_e, fpn_metrics['dice_coeff_mean'],'-o', label='Val dice_coeff', color='#1f77b4')
    plt.plot(n_e, fpn_metrics['iou_metric_mean'],'-o', label='Val dice_coeff', color='#2ca02c')

    def show_max(label = 'dice_metric_mean', col='#ff7f0e'):
        x = np.argmax( fpn_metrics[label] ); y = np.max( fpn_metrics[label] )
        xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color=col); plt.text(x-0.03*xdist,y-0.13*ydist, f'max {label}\n%.2f'%y,size=14)

    show_max('dice_metric_mean', '#ff7f0e')
    show_max('dice_coeff_mean', '#1f77b4')
    show_max('iou_metric_mean', '#2ca02c')

    plt2 = plt.gca().twinx()
    plt2.plot(n_e, fpn_metrics['best_loss'],'-o',label='Val Loss',color='#d62728')

    plt.ylabel('dice_coe',size=14); plt.xlabel('Epoch',size=14)
    plt.legend(loc=2)
    plt2 = plt.gca().twinx()
    plt.legend(loc=3)

# %%
metrics = pd.read_json(PATH/'43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_b12_fold_0')
metrics
# Out:
#     avg_loss  best_loss  dice_coeff_mean  dice_metric_mean  epoch  fold  \
# 0   0.062925   0.062925         0.910690          0.843023      0     0
# 1   0.045443   0.045443         0.930447          0.875190      1     0
# 2   0.044050   0.044050         0.939206          0.881283      2     0
# 3   0.047352   0.044050         0.932979          0.886673      3     0
# 4   0.043528   0.043528         0.937698          0.880987      4     0
# 5   0.042311   0.042311         0.940409          0.887519      5     0
# 6   0.044444   0.042311         0.938884          0.883602      6     0
# 7   0.041932   0.041932         0.941355          0.899889      7     0
# 8   0.042732   0.041932         0.940062          0.889493      8     0
# 9   0.041689   0.041689         0.940983          0.889531      9     0
# 10  0.042114   0.041689         0.943225          0.899317     10     0
# 11  0.043373   0.041689         0.941006          0.884919     11     0
# 12  0.042788   0.041689         0.943085          0.900776     12     0
# 13  0.042363   0.041689         0.942569          0.897045     13     0
# 14  0.042223   0.041689         0.942820          0.901796     14     0
# 15  0.041867   0.041689         0.943789          0.901162     15     0
# 16  0.042477   0.041689         0.942661          0.903780     16     0
# 17  0.041996   0.041689         0.943674          0.903908     17     0
# 18  0.041732   0.041689         0.943946          0.903568     18     0
# 19  0.042066   0.041689         0.943626          0.905393     19     0
#
#     iou_metric_mean
# 0          0.836920
# 1          0.870887
# 2          0.885923
# 3          0.875210
# 4          0.883463
# 5          0.887993
# 6          0.885460
# 7          0.889834
# 8          0.887411
# 9          0.889054
# 10         0.892948
# 11         0.889193
# 12         0.892817
# 13         0.891857
# 14         0.892358
# 15         0.894004
# 16         0.892066
# 17         0.893817
# 18         0.894245
# 19         0.893762

# %%
plot_results(metrics)
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:58: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   return bound(*args, **kwds)
# No handles with labels found to put in legend.

# %%
metrics = pd.read_json(PATH/'43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_b12_fold_1')
metrics
# Out:
#     avg_loss  best_loss  dice_coeff_mean  dice_metric_mean  epoch  fold  \
# 0   0.066015   0.066015         0.898584          0.863694      0     1
# 1   0.042636   0.042636         0.940092          0.911721      1     1
# 2   0.042667   0.042636         0.941333          0.912853      2     1
# 3   0.042627   0.042627         0.939925          0.910308      3     1
# 4   0.041070   0.041070         0.940551          0.913810      4     1
# 5   0.041773   0.041070         0.944416          0.916781      5     1
# 6   0.048477   0.041070         0.935430          0.903043      6     1
# 7   0.042321   0.041070         0.939749          0.913552      7     1
# 8   0.038823   0.038823         0.946733          0.922305      8     1
# 9   0.039273   0.038823         0.946668          0.922290      9     1
# 10  0.040907   0.038823         0.943956          0.919087     10     1
# 11  0.039822   0.038823         0.946044          0.920506     11     1
# 12  0.040101   0.038823         0.945620          0.921623     12     1
# 13  0.040260   0.038823         0.947676          0.923311     13     1
# 14  0.040327   0.038823         0.945888          0.923267     14     1
# 15  0.040503   0.038823         0.946012          0.921917     15     1
# 16  0.041239   0.038823         0.945233          0.923291     16     1
# 17  0.040303   0.038823         0.946670          0.925000     17     1
# 18  0.040426   0.038823         0.946964          0.925964     18     1
# 19  0.040189   0.038823         0.947194          0.924938     19     1
#
#     iou_metric_mean
# 0          0.817919
# 1          0.887492
# 2          0.889834
# 3          0.887270
# 4          0.888350
# 5          0.895187
# 6          0.879796
# 7          0.886975
# 8          0.899338
# 9          0.899190
# 10         0.894402
# 11         0.898067
# 12         0.897383
# 13         0.901005
# 14         0.897794
# 15         0.897988
# 16         0.896608
# 17         0.899204
# 18         0.899709
# 19         0.900108

# %%
plot_results(metrics)
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:58: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   return bound(*args, **kwds)
# No handles with labels found to put in legend.

# %%
metrics = pd.read_json(PATH/'43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_b12_fold_2')
metrics
# Out:
#     avg_loss  best_loss  dice_coeff_mean  dice_metric_mean  epoch  fold  \
# 0   0.073673   0.073673         0.891130          0.834207      0     2
# 1   0.061994   0.061994         0.909829          0.861139      1     2
# 2   0.062936   0.061994         0.905867          0.854296      2     2
# 3   0.064292   0.061994         0.909785          0.864700      3     2
# 4   0.058464   0.058464         0.916472          0.873064      4     2
# 5   0.063006   0.058464         0.908856          0.863604      5     2
# 6   0.059063   0.058464         0.915752          0.874123      6     2
# 7   0.057697   0.057697         0.917538          0.871688      7     2
# 8   0.061805   0.057697         0.912301          0.862920      8     2
# 9   0.065203   0.057697         0.909352          0.858014      9     2
# 10  0.061672   0.057697         0.912690          0.863517     10     2
# 11  0.063230   0.057697         0.912580          0.864623     11     2
#
#     iou_metric_mean
# 0          0.812048
# 1          0.844777
# 2          0.838989
# 3          0.845768
# 4          0.856307
# 5          0.843709
# 6          0.853851
# 7          0.855722
# 8          0.849013
# 9          0.844574
# 10         0.849232
# 11         0.849569

# %%
plot_results(metrics)
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:58: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   return bound(*args, **kwds)
# No handles with labels found to put in legend.

# %%
metrics = pd.read_json(PATH/'43_pytorch_fpn_efficientnet_b7_1536_768_shifted_slices_groupkfold_smooth_b12_fold_3')
metrics
# Out:
#     avg_loss  best_loss  dice_coeff_mean  dice_metric_mean  epoch  fold  \
# 0   0.072540   0.072540         0.894394          0.843070      0     3
# 1   0.057011   0.057011         0.919814          0.876734      1     3
# 2   0.053466   0.053466         0.929409          0.892238      2     3
# 3   0.053025   0.053025         0.930193          0.893099      3     3
# 4   0.054692   0.053025         0.925806          0.890317      4     3
# 5   0.053442   0.053025         0.931109          0.897630      5     3
# 6   0.053692   0.053025         0.927987          0.890963      6     3
# 7   0.045860   0.045860         0.938408          0.906722      7     3
# 8   0.045715   0.045715         0.938777          0.906644      8     3
# 9   0.050515   0.045715         0.935154          0.899767      9     3
# 10  0.049196   0.045715         0.933331          0.895472     10     3
# 11  0.045692   0.045692         0.938931          0.905219     11     3
# 12  0.046102   0.045692         0.940059          0.907334     12     3
# 13  0.045996   0.045692         0.940186          0.907969     13     3
# 14  0.046051   0.045692         0.940325          0.907307     14     3
# 15  0.045836   0.045692         0.940391          0.909428     15     3
# 16  0.046361   0.045692         0.940593          0.909393     16     3
# 17  0.046217   0.045692         0.940242          0.909074     17     3
# 18  0.046732   0.045692         0.940143          0.909054     18     3
# 19  0.046265   0.045692         0.940579          0.909074     19     3
#
#     iou_metric_mean
# 0          0.816147
# 1          0.856584
# 2          0.870705
# 3          0.872072
# 4          0.864834
# 5          0.872002
# 6          0.869999
# 7          0.884695
# 8          0.885404
# 9          0.879543
# 10         0.876710
# 11         0.885697
# 12         0.887627
# 13         0.887904
# 14         0.888054
# 15         0.888244
# 16         0.888540
# 17         0.888106
# 18         0.887855
# 19         0.888624

# %%
plot_results(metrics)
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:58: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   return bound(*args, **kwds)
# No handles with labels found to put in legend.
